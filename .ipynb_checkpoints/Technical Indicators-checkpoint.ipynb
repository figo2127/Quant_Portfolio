# %%
import yfinance as yf
import pandas as pd

# %%
DF = pd.DataFrame()
DF = yf.download(tickers = "AAPL", period = "2021-02-10", interval = "1m")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # MACD - trend-following momentum indicator
# - Moving Average Convergence Divergence
# - 12/26/9
# - lagging indicator

# %%
def MACD(DF, a, b, c):
    df = DF.copy()
    df["MA_FAST"] = df["Adj Close"].ewm(span = a, min_periods = a).mean()
    df["MA_SLOW"] = df["Adj Close"].ewm(span = b, min_periods = b).mean()
    df["MACD"] = df["MA_FAST"] - df["MA_SLOW"]
    df["SIGNAL"] = df["Adj Close"].ewm(span = c, min_periods = c).mean()
    df.dropna(inplace=True)
    df.loc[:, ['Adj Close', 'MACD', 'SIGNAL']].plot(subplots=True, layout = (3,1), grid =True)
    return df

# %%
MACD(DF, 12,26,9)
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2021-02-26 09:55:00-05:00  122.500000  122.500198  122.129997  122.180000
# 2021-02-26 09:56:00-05:00  122.250000  122.264999  122.050003  122.080002
# 2021-02-26 09:57:00-05:00  122.250000  122.279999  122.220001  122.250000
# 2021-02-26 09:58:00-05:00  122.500000  122.510002  122.330002  122.438400
# 2021-02-26 09:59:00-05:00  122.410004  122.489998  122.199997  122.315002
# ...                               ...         ...         ...         ...
# 2021-02-26 15:55:00-05:00  122.940002  123.089996  122.559998  122.739998
# 2021-02-26 15:56:00-05:00  122.730003  123.050003  122.529999  122.639999
# 2021-02-26 15:57:00-05:00  122.644997  122.790001  122.500000  122.580002
# 2021-02-26 15:58:00-05:00  122.580002  122.589996  122.250000  122.321999
# 2021-02-26 15:59:00-05:00  122.330002  122.360001  121.209999  121.209999
#
#                             Adj Close   Volume     MA_FAST     MA_SLOW  \
# Datetime
# 2021-02-26 09:55:00-05:00  122.180000   584562  122.829070  122.950007
# 2021-02-26 09:56:00-05:00  122.080002   531461  122.712548  122.876340
# 2021-02-26 09:57:00-05:00  122.250000   494468  122.640718  122.823862
# 2021-02-26 09:58:00-05:00  122.438400   390186  122.609346  122.791876
# 2021-02-26 09:59:00-05:00  122.315002   400622  122.563758  122.752654
# ...                               ...      ...         ...         ...
# 2021-02-26 15:55:00-05:00  122.739998  1745620  123.767709  123.907997
# 2021-02-26 15:56:00-05:00  122.639999  1208973  123.594215  123.814071
# 2021-02-26 15:57:00-05:00  122.580002  1219933  123.438182  123.722659
# 2021-02-26 15:58:00-05:00  122.321999  1640999  123.266462  123.618906
# 2021-02-26 15:59:00-05:00  121.209999  3549068  122.950083  123.440469
#
#                                MACD      SIGNAL
# Datetime
# 2021-02-26 09:55:00-05:00 -0.120937  122.752767
# 2021-02-26 09:56:00-05:00 -0.163793  122.617888
# 2021-02-26 09:57:00-05:00 -0.183143  122.544167
# 2021-02-26 09:58:00-05:00 -0.182531  122.522981
# 2021-02-26 09:59:00-05:00 -0.188896  122.481334
# ...                             ...         ...
# 2021-02-26 15:55:00-05:00 -0.140288  123.654753
# 2021-02-26 15:56:00-05:00 -0.219856  123.451802
# 2021-02-26 15:57:00-05:00 -0.284476  123.277442
# 2021-02-26 15:58:00-05:00 -0.352444  123.086353
# 2021-02-26 15:59:00-05:00 -0.490386  122.711082
#
# [365 rows x 10 columns]

# %% [markdown]
# # SMA
# - simple moving average

# %%
def SMA(DF, n):
    copy = DF.copy()
    sma = copy.rolling(window=n, min_periods=n).mean() # this will get average of 1 day for the ealier values
    sma = sma.dropna(inplace=True)
    return sma

# %% [markdown]
# # Bollinger Band and ADR - Volatility
# - n: 20

# %%
# Function to calculate true range and average true range
def ATR(DF, n):
    df = DF.copy()
    df["H-L"] = abs(df["High"] - df["Low"]).shift(1)
    df["H-PC"] = abs(df["High"] - df["adj close"]).shift(1)
    df["L-PC"] = abs(df["Low"] - df["adj close"]).shift(1)
    df["TR"] = df[["H-L", "H-PC", "L-PC"]].max(axis=1, skipna=False)
    df["ATR"] = df["TR"].rolling(n).mean()
    df2 = df.drop(["H-L", "H-PC", "L-PC"], axis=1)
    df2 = df.dropna(inplace=True)
    return df2

# %%
def BollBnd(DF, n):
    df = DF.copy()
    df["MA"] = df["Adj Close"].rolling(n).mean()
    df["BB_UP"] = df["MA"] + 2*df["MA"].rolling(n).std()
    df["BB_DOWN"] = df["MA"] - 2*df["MA"].rolling(n).std()
    df["BB_RANGE"] = df["BB_UP"] - df["BB_DOWN"]
    df.dropna(inplace=True)
    return df

# %%
BollBnd(DF,10)
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2021-02-26 09:48:00-05:00  123.000000  123.260002  123.000000  123.249901
# 2021-02-26 09:49:00-05:00  123.250000  123.250000  123.099998  123.195000
# 2021-02-26 09:50:00-05:00  123.125000  123.239998  123.059998  123.209000
# 2021-02-26 09:51:00-05:00  123.000000  123.050003  122.589996  122.650101
# 2021-02-26 09:52:00-05:00  122.669998  122.760002  122.589996  122.620102
# ...                               ...         ...         ...         ...
# 2021-02-26 15:55:00-05:00  122.940002  123.089996  122.559998  122.739998
# 2021-02-26 15:56:00-05:00  122.730003  123.050003  122.529999  122.639999
# 2021-02-26 15:57:00-05:00  122.644997  122.790001  122.500000  122.580002
# 2021-02-26 15:58:00-05:00  122.580002  122.589996  122.250000  122.321999
# 2021-02-26 15:59:00-05:00  122.330002  122.360001  121.209999  121.209999
#
#                             Adj Close   Volume          MA       BB_UP  \
# Datetime
# 2021-02-26 09:48:00-05:00  123.249901   669528  123.350831  123.682176
# 2021-02-26 09:49:00-05:00  123.195000   364257  123.322330  123.582787
# 2021-02-26 09:50:00-05:00  123.209000   495795  123.256380  123.458887
# 2021-02-26 09:51:00-05:00  122.650101   658506  123.160390  123.339987
# 2021-02-26 09:52:00-05:00  122.620102   534701  123.107401  123.284211
# ...                               ...      ...         ...         ...
# 2021-02-26 15:55:00-05:00  122.739998  1745620  124.005881  124.274757
# 2021-02-26 15:56:00-05:00  122.639999  1208973  123.814880  124.202851
# 2021-02-26 15:57:00-05:00  122.580002  1219933  123.618880  124.171789
# 2021-02-26 15:58:00-05:00  122.321999  1640999  123.378080  124.118089
# 2021-02-26 15:59:00-05:00  121.209999  3549068  123.021950  123.988084
#
#                               BB_DOWN  BB_RANGE
# Datetime
# 2021-02-26 09:48:00-05:00  123.019486  0.662690
# 2021-02-26 09:49:00-05:00  123.061874  0.520913
# 2021-02-26 09:50:00-05:00  123.053874  0.405014
# 2021-02-26 09:51:00-05:00  122.980794  0.359192
# 2021-02-26 09:52:00-05:00  122.930590  0.353620
# ...                               ...       ...
# 2021-02-26 15:55:00-05:00  123.737005  0.537752
# 2021-02-26 15:56:00-05:00  123.426910  0.775941
# 2021-02-26 15:57:00-05:00  123.065972  1.105817
# 2021-02-26 15:58:00-05:00  122.638071  1.480017
# 2021-02-26 15:59:00-05:00  122.055815  1.932269
#
# [372 rows x 10 columns]

# %% [markdown]
# # RSI - Relative Strength Indicator
# - momentum ocsilator which measures
# - its strength against its past value(???)
# - developed country: 30(buy)/70(sell)
# - emerging market: 20/80

# %%
def RSI(DF, n):
    df = DF.copy()
    df["delta"] = df["Adj Close"] - df["Adj Close"].shift(1)
    df["gain"] = np.where(df["delta"]>=0, df["delta"], 0)
    df["loss"] = np.where(df["delta"]<0, abs(df["delta"]), 0)
    avg_gain = []
    avg_loss = []
    gain = df["gain"].tolist()
    loss = df["loss"].tolist()
    for i in range(len(df)):
        if i < n:
            avg_gain.append(np.NaN)
            avg_loss.append(np.NaN)
        elif i == n:
            avg_gain.append(df["gain"].rolling(n).mean().tolist()[n])
            avg_loss.append(df["loss"].rolling(n).mean().tolist()[n])
        else:
            avg_gain.append((avg_gain[i - 1]*(n - 1) + gain[i])/n)
            avg_gain.append((avg_loss[i - 1]*(n - 1) + loss[i])/n)
    df["avg_gain"] = np.array(avg_gain)
    df["avg_loss"] = np.array(avg_loss)
    df["RS"] = df["avg_gain"]/df["avg_loss"]
    df["RSI"] = 100 - (100/(1+df["RS"]))
    return df["RSI"]

# %% [markdown]
# # ADX(Average Direactional Index)
# - 0~100
# - 0~25: weak
# - 25~50: strong
# - 50~75: very strong
# - 75~100: extremely strong
# - non-directional

# %%
def ADX(DF, n):
    df2 = DF.copy()
    df2["TR"] = ATR(df2, n)["TR"]
    df2["DMplus"] = np.where((df2["High"] - df2["High"].shift(1))>(df2["Low"].shift(1)-df2["Low"]), 
                             df2["High"] - df2["High"].shift(1),
                             0)
    df2["DMplus"] = np.where(df2["DMplus"]<0, 0, df2["DMplus"])
    df2["DMminus"] = np.where((df2["Low"].shift(1)-df2["Low"])>(df2["High"] - df2["High"].shift(1)),
                             df2["Low"].shift(1)-df2["Low"],
                             0)
    df2["DMminus"] = np.where(df2["DMminus"]<0, 0, df2["DMminus"])
    TRn=[]
    DMplusN=[]
    DMminusN=[]
    DMplus = df2['DMplus'].toList()
    DMminus = df2['DMminus'].toList()
    for i in range(len(df2)):
        if i<n:
            TRn.append(np.NaN)
            DMplusN.append(np.NaN)
            DMminusN.append(np.NaN)
        elif i == n:
            TRn.append(df2["TR"].rolling(n).sum.toList()[n])
            DMplusN.append(df2["DMplus"].rolling(n).tolist()[n])
            DMMinusN.append(df2["DMMinus"].rolling(n).tolist()[n])
        else:
            TRn.append(TRn[i-1] - (TRn[i-1]/14) + TR[i])
            DMplusN.append(DMplusN[i-1] - (DMplusN[i-1]/14) + DMplus[i])
            DMminusN.append(DMminusN[i-1] - (DMminusN[i-1]/14) + DMminus[i])
            
    df2["TRn"] = np.array(TRn)
    df2["DMplusN"] = np.array(DMplusN)
    df2["DMminusN"] = np.array(DMminusN)
    df2["DIplusN"] = 100*(df2["DIplusN"]/df2["TRn"])
    df2["DIminusN"] = 100*(df2["DIminusN"]/df2["TRn"])
    df2["DIsum"] =  df2["DIplusN"] + df2["DIminusN"] 
    df2["DIdiff"] =  abs(df2["DIplusN"] - df2["DIminusN"])
    df2["DX"] = 100*(df2["DIdiff"]/df2["DIsum"])
    ADX = []
    DX = df2["DX"].tolist()
    for j in range(len(df2)):
        if j < 2*n-1:
            ADX.append(np.NaN)
        elif j == 2*n-1:
            ADX.append(df2["DX"][j-n+1: j+1].mean())
        elif j > 2*n-1:
            ADX.append(((n - 1)*ADX[j-1] + DX[j])/n)
    df2["ADX"] =np.array(ADX)
    return df2["ADX"]
